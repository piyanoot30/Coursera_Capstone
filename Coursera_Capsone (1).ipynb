# %%
this is the frist lab of capstone projects
import pandas as pd
import numpy as np
print("Hello captone project course!")
# Out:
#   File "<ipython-input-3-fc2cdb4ed982>", line 1
#     this is the frist lab of capstone projects
#                     ^
# SyntaxError: invalid syntax
